# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
from random import choice

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
options=['stone', 'paper','scissors']


# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
max_games=5

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
number_games=max_games//2+1

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def robot_play():
    return choice(options)


# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def human_play():
    a=input("Please choose one of the following: 'stone', 'paper' or 'scissors' ")
    while a not in options:
        a=input("You've made a mistake, please choose within: 'stone', 'paper' or 'scissors' ")
    return a 



# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
def combat (robot_choice,human_choice):
    win_play={'paper':'stone', 'stone':'scissors','scissors':'paper'}
    print("Robot choice", robot_choice)
    if win_play[robot_choice]==human_choice:
        print("Robot won !")
        return 1   
    
    elif win_play[human_choice]==robot_choice:
        print("You won !")
        return 2
    
    else:
        print("Draw!")
        return 0
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def game_step():
    return combat(robot_play(),human_play())
    
    
# Create two variables that accumulate the wins of each participant
score_robot,score_human,game=(0,0,0)


# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while game<max_games and score_robot<number_games and score_human<number_games:
    result= game_step()
    if result==1:
        score_robot+=1
    elif result==2:
        score_human+=1
    game+=1   

    
# Print by console the winner of the game based on who has more accumulated wins
if score_robot<score_human:
    print("You won !")
elif score_robot>score_human:
    print("Robot is the winner!")
else:
    print("DRAW!")
# Out:
# Please choose one of the following: 'stone', 'paper' or 'scissors' paper
# Robot choice paper
# Draw!
# Please choose one of the following: 'stone', 'paper' or 'scissors' papa
# You've made a mistake, please choose within: 'stone', 'paper' or 'scissors' stone
# Robot choice scissors
# You won !
# Please choose one of the following: 'stone', 'paper' or 'scissors' scissors
# Robot choice paper
# You won !
# Please choose one of the following: 'stone', 'paper' or 'scissors' paper
# Robot choice paper
# Draw!
# Please choose one of the following: 'stone', 'paper' or 'scissors' papa
# You've made a mistake, please choose within: 'stone', 'paper' or 'scissors' stone
# Robot choice paper
# Robot won !
# Human is the winner !

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
from random import choice

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking


# Assign a list of 5 possible options.
options=['stone', 'paper','scissors','lizard','spock']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
max_games=int(input("Enter the number of games "))
while max_games%2 ==0:
    max_games= int(input("The number of games have to be an odd number !! "))

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

number_games=max_games//2+1
# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def robot_play():
    return choice(options)

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def human_play():
    a=input("Please choose one of the following: 'stone', 'paper', 'scissors','lizard' or 'spock' ")
    while a not in options:
        a=input("You've made a mistake, please choose within: 'stone', 'paper','scissors' ,'lizard' or 'spock' ")
    return a 

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
 
def combat (robot_choice,human_choice):
    win_play={'paper': ('stone','spock'), 'stone':('scissors','lizard'),'scissors':('paper','lizard'), 
              'lizard': ('paper', 'spock') ,'spock': ('stone','scissors')}
    print("Robot choice", robot_choice)
    if human_choice in win_play[robot_choice]:
        print("Robot won !")
        return 1   
    
    elif robot_choice in win_play[human_choice]:
        print("You won !")
        return 2
    
    else:
        print("Draw!")
        return 0
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def game_step():
    return combat(robot_play(),human_play())
    
    
# Create two variables that accumulate the wins of each participant
score_robot,score_human,game=(0,0,0)
    
# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while game<max_games and score_robot<number_games and score_human<number_games:
    result= game_step()
    if result==1:
        score_robot+=1
    elif result==2:
        score_human+=1
    game+=1   

    
# Print by console the winner of the game based on who has more accumulated wins
if score_robot<score_human:
    print("You won !", score_human, '-',score_robot)
elif score_robot>score_human:
    print("Robot is the winner!", score_human, '-',score_robot)
else:
    print("DRAW!")
# Out:
# Enter the number of games 5
# Please choose one of the following: 'stone', 'paper', 'scissors','lizard' or 'spock' andjf
# You've made a mistake, please choose within: 'stone', 'paper','scissors' ,'lizard' or 'spock' lizard
# Robot choice spock
# You won !
# Please choose one of the following: 'stone', 'paper', 'scissors','lizard' or 'spock' spock
# Robot choice stone
# You won !
# Please choose one of the following: 'stone', 'paper', 'scissors','lizard' or 'spock' paper
# Robot choice stone
# You won !
# You won !
